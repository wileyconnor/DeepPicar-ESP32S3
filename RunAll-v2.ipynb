# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/heechul/DeepPicar-ESP32S3/blob/main/RunAll-v2.ipynb">
#         <img src="https://i.ibb.co/2P3SLwK/colab.png"  style="padding-bottom:5px;" />Run in Google Colab</a>

# %%
# !pip install -U tf_keras  &> 0 # Keras 2
import os
os.environ["TF_USE_LEGACY_KERAS"] = "1"
print("Packages Installed")
# Out:
# Packages Installed

# %%
import tensorflow as tf
from tensorflow import keras 

import cv2
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
from pandas import read_csv
from sklearn.model_selection import train_test_split
from sklearn.utils import class_weight

import math
# from skimage import data
from skimage import io
from skimage.exposure import match_histograms
print(tf.__version__)
# Out:
# WARNING:tensorflow:From c:\Users\me\Documents\HIII\DeepPicar-ESP32S3\.venv\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# 2.21.0

# %%
use_int8 = True                             # use int8 input tensor
use_finetuning = False                      # use fine tuning after loading initial weights, instead of trainig from scratch

print("use_int8: ", use_int8)
print("use_finetuning: ", use_finetuning)
# Out:
# use_int8:  True
# use_finetuning:  False

# %%
# input image resolution to the DNN model (smaller than the original dataset image resolution: 320x240x3)
img_width = 160
img_height = 60
img_channels = 3
temporal_context = 1  # number of past images to be used as input to the model
ch_frac = 1.0

mode = "resize"  # "crop" or "resize
model_name = "pilotnet-dg"
model_file = "models/{}-{}x{}x{}-T{}-r{}".format(model_name, img_width, img_height, img_channels, temporal_context, ch_frac)

print("model:", model_file)
# Out:
# model: models/pilotnet-dg-160x60x3-T1-r1.0

# %%
import requests 
import os
import zipfile

dataset_dir = "dataset"
dataset_zipfile = 'Dataset.zip' # 'dataset-1229.zip'
RunningInCOLAB = 'google.colab' in str(get_ipython())
force_unzip = False

if RunningInCOLAB: 
    print("in colab")
    from google.colab import files
    uploaded = files.upload()
    for fn in uploaded.keys():
        print('User uploaded file "{name}" with length {length} bytes'.format(
            name=fn, length=len(uploaded[fn])))
        dataset_zipfile = fn  # expecting a zip file to be uploaded. 
else:
    print ("not in colab")

if not os.path.isdir(dataset_dir) or force_unzip==True:
    print ('unzip %s into %s folder' % (dataset_zipfile, dataset_dir))
    zip_ref = zipfile.ZipFile(dataset_zipfile)
    zip_ref.extractall(dataset_dir)
# Out:
# not in colab

# %%
# Train/test data lists
imgs = []
vals = []

def rad2deg(rad):
    return 180.0 * rad / math.pi
def deg2rad(deg):
    return math.pi * deg / 180.0

# Scale the image to the model input size
def get_image_resize(img):
    orig_h, orig_w, orig_c = img.shape
    scaled_img = cv2.resize(img, (img_width, img_height), interpolation=cv2.INTER_NEAREST) 
                    # INTER_NEAREST (one implemented in the esp32-s3), 
                    # INTER_LINEAR, INTER_AREA (default), INTER_CUBIC, INTER_LANCZOS4

    # scale_x = int(orig_w / img_width)
    # scale_y = int(orig_h / img_height)

    # for i in range(img_height):
    #     for j in range(img_width):
    #         for k in range(orig_c):
    #             if scaled_img[i,j,k] != img[i*scale_y,j*scale_x,k]:
    #                 print("error", i, j, k, scaled_img[i,j,k], img[i*scale_y,j*scale_x,k])
    return scaled_img

# Crop the image to the model input size
def get_image_crop(img):
    orig_h, orig_w, _ = img.shape
    startx = int((orig_w - img_width) * 0.5); # crop from both sides
    starty = int((orig_h - img_height) * 0.75); # crop from bottom
    return img[starty:starty+img_height, startx:startx+img_width,:]

def preprocess(img):
    if mode == "crop":
        img = get_image_crop(img)
    elif mode == "resize":  
        img = get_image_resize(img)
    # Convert to grayscale and readd channel dimension
    if img_channels == 1:
        img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        img = np.reshape(img, (img_height, img_width, img_channels))
    if use_int8 == True:
        img = (img - 128).astype(np.int8)
    else:
        img = img.astype(np.float32) / 255.0
    return img

import glob
for vid_file_path in glob.iglob(f'{dataset_dir}/*.avi'):
    csv_file_path = vid_file_path.replace('video', 'key').replace('avi', 'csv')
    print(vid_file_path, csv_file_path)
    vid = cv2.VideoCapture(vid_file_path)
    df = read_csv(csv_file_path)

    # Read the video and steering angle data
    # keep 3 past images for temporal context
    temporal_context_buffer = []

    for val in df["wheel"].values:
        ret,img = vid.read()
        img = preprocess(img)

        # add temporal context to the input image
        temporal_context_buffer.append(img)
        if len(temporal_context_buffer) < temporal_context:
            for i in range(temporal_context - len(temporal_context_buffer)):
                temporal_context_buffer.append(img)
        elif len(temporal_context_buffer) > temporal_context:
            temporal_context_buffer.pop(0)   

        img = np.concatenate(temporal_context_buffer, axis=2)
        # print (img.shape)
        imgs.append(img)
        vals.append(val)
    print(len(imgs), len(vals))

# Convert lists to numpy arrays and ensure they are of equal length    
imgs = np.asarray(imgs)  # input images
vals = np.asarray(vals)  # steering angles
assert len(imgs) == len(vals)
print("Loaded {} smaples".format(len(imgs)))
# Out:
# dataset\out-video.avi dataset\out-key.csv
# 1000 1000
# Loaded 1000 smaples

# %%
# Split the dataset for train and test 
print("Train/Test")
x_train, x_test, y_train, y_test = train_test_split(imgs, vals, test_size=0.25)

class_weights = class_weight.compute_class_weight(class_weight='balanced', classes=np.unique(y_train), y=y_train)
print("class_weights", class_weights)
class_weights = {i:class_weights[i] for i in range(len(class_weights))}
print("class_weights", class_weights)
# Out:
# Train/Test
# class_weights [1.38888889 0.78125   ]
# class_weights {0: np.float64(1.3888888888888888), 1: np.float64(0.78125)}

# %%
len(x_train)

os.environ["TF_USE_LEGACY_KERAS"] = "1"

print("channels fraction: ", ch_frac)
# print img_height, img_width, img_channels*temporal_context)
print("model input shape: ", (img_height, img_width, img_channels*temporal_context))

model = tf.keras.models.Sequential([
    tf.keras.layers.Input(shape=(img_height, img_width, img_channels*temporal_context)),
    tf.keras.layers.Conv2D(24*ch_frac, (5, 5), strides = (2,2), activation='relu'),
    tf.keras.layers.Conv2D(36*ch_frac, (5, 5), strides = (2,2), activation='relu'),
    tf.keras.layers.Conv2D(48*ch_frac, (3, 3), strides = (2,2), activation='relu'),
    tf.keras.layers.Conv2D(64*ch_frac, (3, 3), activation='relu'),
    tf.keras.layers.Conv2D(64*ch_frac, (3, 3), activation='relu'),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dropout(0.4),
    tf.keras.layers.Dense(100, activation='relu'),
    tf.keras.layers.Dropout(0.3),
    tf.keras.layers.Dense(50, activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(10, activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(1, name="output", activation='tanh')
    ])
model.summary()
# Out:
# channels fraction:  1.0
# model input shape:  (60, 160, 3)
# WARNING:tensorflow:From c:\Users\me\Documents\HIII\DeepPicar-ESP32S3\.venv\Lib\site-packages\tf_keras\src\backend.py:1400: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 28, 78, 24)        1824
#
#  conv2d_1 (Conv2D)           (None, 12, 37, 36)        21636
#
#  conv2d_2 (Conv2D)           (None, 5, 18, 48)         15600
#
#  conv2d_3 (Conv2D)           (None, 3, 16, 64)         27712
#
#  conv2d_4 (Conv2D)           (None, 1, 14, 64)         36928
#
#  flatten (Flatten)           (None, 896)               0
#
#  dropout (Dropout)           (None, 896)               0
#
#  dense (Dense)               (None, 100)               89700
#
#  dropout_1 (Dropout)         (None, 100)               0
#
#  dense_1 (Dense)             (None, 50)                5050
#
#  dropout_2 (Dropout)         (None, 50)                0
#
#  dense_2 (Dense)             (None, 10)                510
#
#  dropout_3 (Dropout)         (None, 10)                0
#
#  output (Dense)              (None, 1)                 11
#
# =================================================================
# Total params: 198971 (777.23 KB)
# Trainable params: 198971 (777.23 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# a function to calculate MACs and FLOPs of the model
def calc_MAC_FLOPs(model):
    MACs = 0
    FLOPs = 0
    print ("layer name, output shape, MACs, FLOPs")
    for layer in model.layers:
        if isinstance(layer, tf.keras.layers.Conv2D):
            _, Ho, Wo, Co = layer.output_shape # batch, height, width, channels
            Kh, Kw, Ci, _ = layer.kernel.shape # kernel height, kernel width, input channels, output channels
            mac = Ho * Wo * Co * Kh * Kw * Ci
            flop = 2 * mac
        elif isinstance(layer, tf.keras.layers.Dense):
            _, Co = layer.output_shape # batch, output channels
            Ci, _ = layer.kernel.shape # input channels, output channels
            mac = Ci * Co
            flop = 2 * mac
        elif isinstance(layer, tf.keras.layers.Flatten):
            mac = 0
            flop = 0
        elif isinstance(layer, tf.keras.layers.Dropout):
            # skip dropout layer
            continue
        elif isinstance(layer, tf.keras.layers.BatchNormalization):
            # skip batch normalization layer
            continue
        elif isinstance(layer, tf.keras.layers.Activation):
            # skip activation layer
            continue
        else:
            raise Exception("unknown layer type")
        MACs += mac
        FLOPs += flop
        print(layer.name, layer.output_shape, mac, flop)

    return MACs, FLOPs

macs, _ = calc_MAC_FLOPs(model)
print("MACs: ", macs)
# Out:
# layer name, output shape, MACs, FLOPs
# conv2d (None, 28, 78, 24) 3931200 7862400
# conv2d_1 (None, 12, 37, 36) 9590400 19180800
# conv2d_2 (None, 5, 18, 48) 1399680 2799360
# conv2d_3 (None, 3, 16, 64) 1327104 2654208
# conv2d_4 (None, 1, 14, 64) 516096 1032192
# flatten (None, 896) 0 0
# dense (None, 100) 89600 179200
# dense_1 (None, 50) 5000 10000
# dense_2 (None, 10) 500 1000
# output (None, 1) 10 20
# MACs:  16859590

# %%
print ("Model compile")
model.compile(optimizer=tf.keras.optimizers.legacy.Adam(3e-4),
		                loss=tf.keras.losses.MeanSquaredError())
model.summary()
# Out:
# Model compile
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 28, 78, 24)        1824
#
#  conv2d_1 (Conv2D)           (None, 12, 37, 36)        21636
#
#  conv2d_2 (Conv2D)           (None, 5, 18, 48)         15600
#
#  conv2d_3 (Conv2D)           (None, 3, 16, 64)         27712
#
#  conv2d_4 (Conv2D)           (None, 1, 14, 64)         36928
#
#  flatten (Flatten)           (None, 896)               0
#
#  dropout (Dropout)           (None, 896)               0
#
#  dense (Dense)               (None, 100)               89700
#
#  dropout_1 (Dropout)         (None, 100)               0
#
#  dense_1 (Dense)             (None, 50)                5050
#
#  dropout_2 (Dropout)         (None, 50)                0
#
#  dense_2 (Dense)             (None, 10)                510
#
#  dropout_3 (Dropout)         (None, 10)                0
#
#  output (Dense)              (None, 1)                 11
#
# =================================================================
# Total params: 198971 (777.23 KB)
# Trainable params: 198971 (777.23 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# class_weights = class_weight.compute_class_weight(class_weight='balanced', classes=np.unique(y_train), y=y_train)
# class_weights = {i:class_weights[i] for i in range(len(class_weights))}
# print("class_weights", class_weights)

if use_finetuning:
    model.load_weights(model_file + ".h5")
    print("loaded weights from", model_file + ".h5")
    n_epochs = 5
else:
    n_epochs = 40

# Continue with the rest of the code
print ("Model fit")
# model.reset_states()
history = model.fit(x_train, y_train, batch_size=128,
                    epochs=n_epochs, validation_data=(x_test, y_test), 
                    callbacks=[tf.keras.callbacks.EarlyStopping(patience=5, restore_best_weights=True)],
                    )

# Plot training and validation losses 
print(history.history.keys())
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# Model fit
# Epoch 1/40
# WARNING:tensorflow:From c:\Users\me\Documents\HIII\DeepPicar-ESP32S3\.venv\Lib\site-packages\tf_keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 6/6 [==============================] - 2s 145ms/step - loss: 0.7649 - val_loss: 0.7196
# Epoch 2/40
# 6/6 [==============================] - 1s 109ms/step - loss: 0.7314 - val_loss: 0.7329
# Epoch 3/40
# 6/6 [==============================] - 1s 112ms/step - loss: 0.6872 - val_loss: 0.7337
# Epoch 4/40
# 6/6 [==============================] - 1s 107ms/step - loss: 0.6864 - val_loss: 0.7175
# Epoch 5/40
# 6/6 [==============================] - 1s 109ms/step - loss: 0.6590 - val_loss: 0.6024
# Epoch 6/40
# 6/6 [==============================] - 1s 106ms/step - loss: 0.6013 - val_loss: 0.3112
# Epoch 7/40
# 6/6 [==============================] - 1s 110ms/step - loss: 0.4705 - val_loss: 0.0840
# Epoch 8/40
# 6/6 [==============================] - 1s 105ms/step - loss: 0.2703 - val_loss: 0.0770
# Epoch 9/40
# 6/6 [==============================] - 1s 107ms/step - loss: 0.1431 - val_loss: 0.0693
# Epoch 10/40
# 6/6 [==============================] - 1s 105ms/step - loss: 0.1004 - val_loss: 0.0654
# Epoch 11/40
# 6/6 [==============================] - 1s 104ms/step - loss: 0.0859 - val_loss: 0.0653
# Epoch 12/40
# 6/6 [==============================] - 1s 102ms/step - loss: 0.0796 - val_loss: 0.0622
# Epoch 13/40
# 6/6 [==============================] - 1s 104ms/step - loss: 0.0704 - val_loss: 0.0607
# Epoch 14/40
# 6/6 [==============================] - 1s 108ms/step - loss: 0.0728 - val_loss: 0.0579
# Epoch 15/40
# 6/6 [==============================] - 1s 127ms/step - loss: 0.0669 - val_loss: 0.0573
# Epoch 16/40
# 6/6 [==============================] - 1s 123ms/step - loss: 0.0650 - val_loss: 0.0557
# Epoch 17/40
# 6/6 [==============================] - 1s 112ms/step - loss: 0.0591 - val_loss: 0.0525
# Epoch 18/40
# 6/6 [==============================] - 1s 118ms/step - loss: 0.0608 - val_loss: 0.0480
# Epoch 19/40
# 6/6 [==============================] - 1s 117ms/step - loss: 0.0556 - val_loss: 0.0472
# Epoch 20/40
# 6/6 [==============================] - 1s 117ms/step - loss: 0.0554 - val_loss: 0.0474
# Epoch 21/40
# 6/6 [==============================] - 1s 111ms/step - loss: 0.0560 - val_loss: 0.0465
# Epoch 22/40
# 6/6 [==============================] - 1s 108ms/step - loss: 0.0520 - val_loss: 0.0458
# Epoch 23/40
# 6/6 [==============================] - 1s 107ms/step - loss: 0.0501 - val_loss: 0.0444
# Epoch 24/40
# 6/6 [==============================] - 1s 105ms/step - loss: 0.0491 - val_loss: 0.0423
# Epoch 25/40
# 6/6 [==============================] - 1s 105ms/step - loss: 0.0525 - val_loss: 0.0387
# Epoch 26/40
# 6/6 [==============================] - 1s 106ms/step - loss: 0.0496 - val_loss: 0.0379
# Epoch 27/40
# 6/6 [==============================] - 1s 120ms/step - loss: 0.0470 - val_loss: 0.0396
# Epoch 28/40
# 6/6 [==============================] - 1s 119ms/step - loss: 0.0456 - val_loss: 0.0382
# Epoch 29/40
# 6/6 [==============================] - 1s 137ms/step - loss: 0.0414 - val_loss: 0.0358
# Epoch 30/40
# 6/6 [==============================] - 1s 190ms/step - loss: 0.0433 - val_loss: 0.0342
# Epoch 31/40
# 6/6 [==============================] - 1s 153ms/step - loss: 0.0377 - val_loss: 0.0333
# Epoch 32/40
# 6/6 [==============================] - 1s 140ms/step - loss: 0.0372 - val_loss: 0.0316
# Epoch 33/40
# 6/6 [==============================] - 1s 119ms/step - loss: 0.0377 - val_loss: 0.0308
# Epoch 34/40
# 6/6 [==============================] - 1s 148ms/step - loss: 0.0386 - val_loss: 0.0287
# Epoch 35/40
# 6/6 [==============================] - 1s 153ms/step - loss: 0.0368 - val_loss: 0.0293
# Epoch 36/40
# 6/6 [==============================] - 1s 120ms/step - loss: 0.0361 - val_loss: 0.0309
# Epoch 37/40
# 6/6 [==============================] - 1s 114ms/step - loss: 0.0352 - val_loss: 0.0315
# Epoch 38/40
# 6/6 [==============================] - 1s 105ms/step - loss: 0.0335 - val_loss: 0.0289
# Epoch 39/40
# 6/6 [==============================] - 1s 105ms/step - loss: 0.0313 - val_loss: 0.0261
# Epoch 40/40
# 6/6 [==============================] - 1s 108ms/step - loss: 0.0330 - val_loss: 0.0261
# dict_keys(['loss', 'val_loss'])

# %%
angle_thresh=10
# Helper functions for evaluating model accuracy

def get_action(angle_rad):
  degree = rad2deg(angle_rad)
  if degree < angle_thresh and degree > -angle_thresh:
    return "center"
  elif degree >= angle_thresh:
    return "right" 
  elif degree <-angle_thresh:
    return "left"

pred_angle = model.predict(x_test)
pred = np.array(list(map(get_action, pred_angle)))
ground = np.array(list(map(get_action, y_test)))
print('Accuracy is %.3f' % np.mean(pred == ground))
# Out:
# 8/8 [==============================] - 0s 12ms/step
# Accuracy is 0.904

# %% [markdown]
# visualization

# %%
print(pred_angle[0])
# Out:
# [-0.04941718]

# %%
def plot_image(i, prediction_array, groundtrue_array, img_array):
  angle, predicted_label, groundtrue_label, img = int(rad2deg(pred_angle[i])[0]), prediction_array[i], groundtrue_array[i], img_array[i]
  plt.grid(True)
  plt.xticks([])
  plt.yticks([])
  if use_int8 == True:
    img = np.round((img + 128.0) / 255.0, 2)
  else:
    img = np.squeeze(img)
  
  img_buffer = []
  for i in range(temporal_context):
    img_buffer.append(img[:,:,i*3:(i+1)*3])
  img = np.concatenate(img_buffer, axis=1)
  plt.imshow(img, cmap=plt.cm.binary)
  if predicted_label == groundtrue_label:
    color = 'green'
  else:
    color = 'red'  
  plt.xlabel("Predict:{} ({}) Actual:{}".format(predicted_label,angle,groundtrue_label), color=color)

# %%
#@title Visualize the outputs { run: "auto" }
index = 200 #@param {type:"slider", min:0, max:244, step:6}
for i in range(3):
  plt.figure(figsize=(10,3))
  plt.subplot(1,2,1)
  plot_image(index + 2*i, pred, ground, x_test)
  plt.subplot(1,2,2)
  plot_image(index + 2*i+1, pred, ground, x_test)
  plt.show()

# %% [markdown]
# generate image cpp files for testing

# %%
# Save both the Keras and TFLite models      
print("Model Save")              
model.save(model_file+".h5")

def representative_dataset():
    for data in x_test[:300]:   # e.g., 100–500 samples
        yield [np.expand_dims(data.astype(np.float32), axis=0)]


print("TFLite Model")
print("Model input dtype:", model.input.dtype)
print("Model output dtype:", model.output.dtype) 
print("Model Input shape:", model.input.shape)

converter = tf.lite.TFLiteConverter.from_keras_model(model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
converter.representative_dataset = representative_dataset
converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS_INT8]
converter.inference_input_type = tf.int8
converter.inference_output_type = tf.int8

print("Quantize the model")
quantized_tflite_model = converter.convert()

with open(model_file+".tflite", 'wb') as f:
    f.write(quantized_tflite_model)

print (model_file+".tflite is saved. copy this file to the robot")

if RunningInCOLAB: 
    from google.colab import files
    files.download(model_file+".tflite")
# Out:
# Model Save
# TFLite Model
# Model input dtype: <dtype: 'float32'>
# Model output dtype: <dtype: 'float32'>
# Model Input shape: (None, 60, 160, 3)
# Quantize the model
# c:\Users\me\Documents\HIII\DeepPicar-ESP32S3\.venv\Lib\site-packages\tf_keras\src\engine\training.py:3098: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native TF-Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# INFO:tensorflow:Assets written to: C:\Users\me\AppData\Local\Temp\tmpjqycqtrb\assets
# INFO:tensorflow:Assets written to: C:\Users\me\AppData\Local\Temp\tmpjqycqtrb\assets
# c:\Users\me\Documents\HIII\DeepPicar-ESP32S3\.venv\Lib\site-packages\tensorflow\lite\python\convert.py:846: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn(
# models/pilotnet-dg-160x60x3-T1-r1.0.tflite is saved. copy this file to the robot

# %% [markdown]
# generate cc file from tflite model

# %%
import subprocess
import re
import os

# Convert .tflite to C array using Python (replaces xxd)
with open(f"{model_file}.tflite", "rb") as f:
    data = f.read()

hex_values = ", ".join(f"0x{b:02x}" for b in data)
length = len(data)
cc_content = f"unsigned char gmodel[] = {{\n  {hex_values}\n}};\nunsigned int gmodel_len = {length};\n"

with open(f"{model_file}.cc", "w") as f:
    f.write(cc_content)

print(model_file + ".cc --> src/model.h")

# Replace 'unsigned' with 'const unsigned' (replaces sed)
with open(f"{model_file}.cc", "r") as f:
    content = f.read()

content = content.replace("unsigned", "const unsigned")

os.makedirs("src", exist_ok=True)
with open("src/model.h", "w") as f:
    f.write(content)
# Out:
# models/pilotnet-dg-160x60x3-T1-r1.0.cc --> src/model.h

# %%
idx=100
img = x_test[idx]
# Write a C source file of the image for debugging purposes (to check if the model output is correct)
with open('src/img.h', 'w') as f:
    f.write('#ifndef IMG_TEST_DATA\n')
    f.write('#define IMG_TEST_DATA\n')
    f.write('const signed char img_data[] = {')
    for i in range(0, len(img.flatten())):
        f.write(str(img.flatten()[i]))
        if i < len(img.flatten()) - 1:
            f.write(',')    
    f.write('};\n')
    f.write('#endif\n')

plot_image(idx, pred, ground, x_test)
print(pred_angle[idx])
print("Predicted: {} (rad:{}, deg:{})".format(get_action(pred_angle[idx]), pred_angle[idx], rad2deg(pred_angle[idx])))
print("Actual: ", get_action(y_test[idx]))
plt.show()
# Out:
# [-0.43381095]
# Predicted: left (rad:[-0.43381095], deg:[-24.855536])
# Actual:  left

# %% [markdown]
# ### Inference

# %%
print("test img idx: {}, shape: {}".format(idx, img.shape))
print(img.flatten())

interpreter = tf.lite.Interpreter(model_content=quantized_tflite_model)
interpreter.allocate_tensors()
input_index = interpreter.get_input_details()[0]["index"]
output_index = interpreter.get_output_details()[0]["index"]
interpreter.set_tensor(input_index, np.expand_dims(img, axis=0))

input_type = interpreter.get_input_details()[0]['dtype']
print('input: ', input_type)
output_type = interpreter.get_output_details()[0]['dtype']
print('output: ', output_type)

interpreter.invoke()
if output_type == np.int8:
    q = interpreter.get_tensor(output_index)[0][0]
    scale = interpreter.get_output_details()[0]['quantization_parameters']['scales'][0]
    zero_point = interpreter.get_output_details()[0]['quantization_parameters']['zero_points'][0]
    print('scale, zero_point: ', scale, zero_point)
    angle = (q - zero_point) * scale
    print("Predicted: {} (q:{}, rad:{}, deg:{})".format(get_action(angle), q, angle, rad2deg(angle)))
else:
    pred_angle = interpreter.get_tensor(output_index)[0][0]
    print("Predicted: {} (rad:{}, deg:{})".format(get_action(pred_angle), pred_angle, rad2deg(pred_angle)))
# Out:
# test img idx: 100, shape: (60, 160, 3)
# [-48 -12 -17 ... -74 -61 -67]
# input:  <class 'numpy.int8'>
# output:  <class 'numpy.int8'>
# scale, zero_point:  0.0078125 0
# Predicted: left (q:-56, rad:-0.4375, deg:-25.066903536973516)
# c:\Users\me\Documents\HIII\DeepPicar-ESP32S3\.venv\Lib\site-packages\tensorflow\lite\python\interpreter.py:457: UserWarning:     Warning: tf.lite.Interpreter is deprecated and is scheduled for deletion in
#     TF 2.20. Please use the LiteRT interpreter from the ai_edge_litert package.
#     See the [migration guide](https://ai.google.dev/edge/litert/migration)
#     for details.
#
#   warnings.warn(_INTERPRETER_DELETION_WARNING)

# %%
interpreter = tf.lite.Interpreter(model_content=quantized_tflite_model)
interpreter.allocate_tensors()

input_index = interpreter.get_input_details()[0]["index"]
output_index = interpreter.get_output_details()[0]["index"]
if output_type == np.int8:
    scale = interpreter.get_output_details()[0]['quantization_parameters']['scales'][0]
    zero_point = interpreter.get_output_details()[0]['quantization_parameters']['zero_points'][0]

pred_angle_q = []
for img in x_test:
    interpreter.set_tensor(input_index, np.expand_dims(img, axis=0))
    interpreter.invoke()
    if output_type == np.int8:
        q = interpreter.get_tensor(output_index)[0][0]
        angle = (q - zero_point) * scale
    else:
        angle = interpreter.get_tensor(output_index)[0][0]
    pred_angle_q.append(angle)

pred_q = np.array(list(map(get_action, pred_angle_q)))
ground = np.array(list(map(get_action, y_test)))
print('Accuracy is %.3f' % np.mean(pred_q == ground))
print('float vs. quantized model same prediction prob: %.3f' % np.mean(pred_q == pred))
# Out:
# Accuracy is 0.904
# float vs. quantized model same prediction prob: 1.000

# %%
print('Accuracy is %.3f' % np.mean(pred_q == ground))
# Out:
# Accuracy is 0.904
